# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvaraj-212/projects/blob/main/4th%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.Series(np.random.randn(6),index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]])
print(data)
print(data['b'])
print(data[:,1])
# Out:
# a  1    1.220891
#    2   -0.075808
# b  1    0.926616
#    2    0.188674
# c  1   -0.356674
#    2    0.326127
# dtype: float64
# 1    0.926616
# 2    0.188674
# dtype: float64
# a    1.220891
# b    0.926616
# c   -0.356674
# dtype: float64

# %%
df=data.unstack();
print(df);
print(df.stack())
# Out:
#           1         2
# a  1.220891 -0.075808
# b  0.926616  0.188674
# c -0.356674  0.326127
# a  1    1.220891
#    2   -0.075808
# b  1    0.926616
#    2    0.188674
# c  1   -0.356674
#    2    0.326127
# dtype: float64

# %%
# Out:
# Parsed JSON Data
#    Roll_No      Name  Marks
# 0      101    Anusha     89
# 1      102   Babitha     92
# 2      103  Charitha     88

# %%
df1=pd.DataFrame({'a':[1,np.nan,3],'b':[4,5,6,]})
df2=pd.DataFrame({'a':[7,8,9],'b':[np.nan,11,12]})
merged=df1.combine_first(df2)
print(merged)
# Out:
#      a    b
# 0  1.0  4.0
# 1  8.0  5.0
# 2  3.0  6.0
